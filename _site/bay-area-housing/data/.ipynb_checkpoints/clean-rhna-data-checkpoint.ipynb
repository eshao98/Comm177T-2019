# %%
import pandas as pd
import csv

# %%
hw = pd.read_csv("hwdata.csv", sep=",")
hw.head()
# Out:
#    year    zip  onebr  twobr  threebr  fourbr  onehw  twohw  threehw  fourhw  \
# 0  2011  94002   1390   1640     2210    2580  26.73  31.54    42.50   49.62
# 1  2011  94005   1390   1630     2190    2560  26.73  31.35    42.12   49.23
# 2  2011  94010   1290   1520     2040    2390  24.81  29.23    39.23   45.96
# 3  2011  94014   1260   1480     1990    2330  24.23  28.46    38.27   44.81
# 4  2011  94015   1460   1720     2310    2710  28.08  33.08    44.42   52.12
#
#          city            county
# 0     Belmont  San Mateo County
# 1    Brisbane  San Mateo County
# 2  Burlingame  San Mateo County
# 3   Daly City  San Mateo County
# 4   Daly City  San Mateo County

# %%
rhna = pd.read_csv("rhna-data.csv")
rhna.head()
# Out:
#              city   county  vlrhna  totalvl percentvl  lowrhna  lowtotal  \
# 0  Alameda County  Alameda    9912     1270       13%     6604       716
# 1         Alameda  Alameda     444       51       11%      248        33
# 2          Albany  Alameda      80        0        0%       53         0
# 3        Berkeley  Alameda     532       89       17%      442        29
# 4          Dublin  Alameda     796       26        3%      446        39
#
#   lowpercent  modrhna  modtotal modpercent  aboverhna  abovetotal  \
# 0        11%     7924       778        10%      19596       16425
# 1        13%      283        21         7%        748         194
# 2         0%       57         0         0%        145         210
# 3         7%      584         2         0%       1401         817
# 4         9%      425        14         3%        618        2638
#
#   abovepercent  totalrhna  totaltotal totalpercent
# 0          84%      44036       19189          44%
# ...

# %%
merged = pd.merge(hw, rhna, on="city", how="left")

# %%
merged.to_csv("data.csv")
