# %%
import csv
import pandas as pd

# %%
rhna = pd.read_csv("rhna-data.csv")

# %%
rhna.head()
# Out:
#      jurisdiction  vlrhna  vltotal vlpercent  lowrhna  lowtotal lowpercent  \
# 0  Alameda County    9912     1270       13%     6604       716        11%
# 1         Alameda     444       51       11%      248        33        13%
# 2          Albany      80        0        0%       53         0         0%
# 3        Berkeley     532       89       17%      442        29         7%
# 4          Dublin     796       26        3%      446        39         9%
#
#    modrhna  modtotal modpercent  aboverhna  abovetotal abovepercent  \
# 0     7924       778        10%      19596       16425          84%
# 1      283        21         7%        748         194          26%
# 2       57         0         0%        145         210         145%
# 3      584         2         0%       1401         817          58%
# 4      425        14         3%        618        2638         427%
#
#    totalrhna  totaltotal totalpercent
# 0      44036       19189          44%
# ...

# %%
rhna.pivot(index='vlrhna', columns='jurisdiction')
# Out:
#              vltotal                                                        \
# jurisdiction Alameda Alameda County Alameda Unincorporated Albany Atherton
# vlrhna
# 20               NaN            NaN                    NaN    NaN      NaN
# 21               NaN            NaN                    NaN    NaN      NaN
# 22               NaN            NaN                    NaN    NaN      NaN
# 23               NaN            NaN                    NaN    NaN      NaN
# 24               NaN            NaN                    NaN    NaN      NaN
# 25               NaN            NaN                    NaN    NaN      NaN
# 32               NaN            NaN                    NaN    NaN      NaN
# 35               NaN            NaN                    NaN    NaN     15.0
# 46               NaN            NaN                    NaN    NaN      NaN
# 52               NaN            NaN                    NaN    NaN      NaN
# ...
